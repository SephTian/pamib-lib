# %%
import PAMI.extras.dbStats.transactionalDatabaseStats as stats1
#Nama: Joseph Christian
#Kelas: C14200200

obj = stats1.transactionalDatabaseStats('transactional_T10I4D100K.csv', '\t')
obj.run()
obj.printStats()
obj.plotGraphs()
# Out:
# Database size (total no of transactions) : 6257
# Number of items : 1534
# Minimum Transaction Size : 1
# Average Transaction Size : 10.087262266261787
# Maximum Transaction Size : 25
# Standard Deviation Transaction Size : 3.708155377294882
# Variance in Transaction Sizes : 13.752614258730988
# Sparsity : 0.9934242097351618

# %%
import PAMI.extras.dbStats.temporalDatabaseStats as stats2
obj = stats2.temporalDatabaseStats('Temporal_T10I4D100K.csv', '\t')
obj.run()
obj.printStats()
obj.plotGraphs()
# Out:
# Database size : 99913
# Number of items : 870
# Minimum Transaction Size : 1
# Average Transaction Size : 10.10182859087406
# Maximum Transaction Size : 29
# Minimum period : 1
# Average period : 1.0
# Maximum period : 1
# Standard Deviation Transaction Size : 3.667115963877195
# Variance : 13.447874088362232
# Sparsity : 0.9883887027691103
